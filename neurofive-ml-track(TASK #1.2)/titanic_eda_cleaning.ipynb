# %% [markdown]
# # Task 1(PT2): Data Cleaning + Visualization — Titanic Dataset
# **Neurofive ML Track**
#
# This notebook focuses on data cleaning and exploratory data analysis (EDA). We will handle missing values, detect outliers, and use data visualizations to understand the relationships between features and identify the factors that most significantly influence passenger survival.
